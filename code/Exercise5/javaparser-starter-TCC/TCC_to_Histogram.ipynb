# %% [markdown]
# # Libraries imports

# %%
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt

# %% [markdown]
# # Data import

# %%
df1 = pd.read_csv("output.csv")
df1=df1.dropna()
df1
# Out:
#                                   Package                  Class Name  \
# 0         org.apache.commons.collections4                  ArrayStack
# 2     org.apache.commons.collections4.bag        AbstractBagDecorator
# 3     org.apache.commons.collections4.bag              AbstractMapBag
# 4     org.apache.commons.collections4.bag  AbstractSortedBagDecorator
# 5     org.apache.commons.collections4.bag               CollectionBag
# ..                                    ...                         ...
# 564       org.apache.commons.collections4        TransformerUtilsTest
# 565  org.apache.commons.collections4.trie           PatriciaTrie2Test
# 566  org.apache.commons.collections4.trie            PatriciaTrieTest
# 567  org.apache.commons.collections4.trie        UnmodifiableTrieTest
# 568       org.apache.commons.collections4               TrieUtilsTest
#
#      TCC value
# 0     0.000000
# 2     0.000000
# 3     0.276667
# 4     0.000000
# 5     0.000000
# ..         ...
# ...

# %%
df2 = pd.read_csv("output2.csv")
df2=df2.dropna()
df2
# Out:
#                        Package                   Class Name  TCC value
# 0       org.apache.commons.cli     AlreadySelectedException   0.000000
# 1       org.apache.commons.cli     AmbiguousOptionException   1.000000
# 2       org.apache.commons.cli                  BasicParser   0.000000
# 3       org.apache.commons.cli                      Builder   1.000000
# 4       org.apache.commons.cli            CommandLineParser   0.000000
# 5       org.apache.commons.cli                      Builder   0.666667
# 6       org.apache.commons.cli                    GnuParser   0.000000
# 7       org.apache.commons.cli                HelpFormatter   0.018293
# 8       org.apache.commons.cli     MissingArgumentException   0.000000
# 9       org.apache.commons.cli       MissingOptionException   1.000000
# 10      org.apache.commons.cli                      Builder   0.047619
# 11      org.apache.commons.cli                OptionBuilder   0.289474
# ...

# %% [markdown]
# # TCC histogram for projects

# %%
plt.figure(figsize=(15,15))
plt.subplot(2, 2, 1)
sb.histplot(data = df1, x="TCC value")
plt.title("Commons collections master")
plt.subplot(2, 2, 2)
plt.title("Commons cli master")
sb.histplot(data = df2, x="TCC value")
plt.show()
